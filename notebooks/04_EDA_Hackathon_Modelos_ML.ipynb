# %% [markdown]
# # EDA - xploratory Analisis of spotify_modelos_final
#
# En este notenook dearrollaremos un análisis exploratorio de las nuevas características para el archivo (.cs) generado por los modelos de machine learning.

# %%
# Cargamos la librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Cargamos el dataset
df = pd.read_csv('data\processed\spotify_modelos_final.csv')
