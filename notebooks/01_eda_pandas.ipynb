# %% [markdown]
# # Spotify Streaming Audit, Hackathon - Grupo #3
#
# ## Exploring Data Analisys

# %%
# Cargamos las librerías necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Importamos los datasets y creamos los dataframes

# %%
# Cargamos los datos de Spotify desde el archivo CSV
raw_spotify_data = pd.read_csv('../data/raw/Spotify-2000.csv')

# Cargamos los datos de los Grammy Awards desde el archivo CSV
raw_grammy_data = pd.read_csv('../data/raw/the_grammy_awards.csv')

# Revisamos el tamaño de los datasets
print(f"Spotify Data Shape: {raw_spotify_data.shape}")
print(f"Grammy Data Shape: {raw_grammy_data.shape}")
# Out:
# Spotify Data Shape: (1994, 15)
# Grammy Data Shape: (4810, 10)

# %% [markdown]
# Visualizamos el contenido de ambos dataframes
#
# ### Spotify dataframe

# %%
# Visualizamos la información general del dataframe de Spotify
raw_spotify_data.info()
raw_spotify_data.head(10).T
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1994 entries, 0 to 1993
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Index                   1994 non-null   int64
#  1   Title                   1994 non-null   str
#  2   Artist                  1994 non-null   str
#  3   Top Genre               1994 non-null   str
#  4   Year                    1994 non-null   int64
#  5   Beats Per Minute (BPM)  1994 non-null   int64
#  6   Energy                  1994 non-null   int64
#  7   Danceability            1994 non-null   int64
#  8   Loudness (dB)           1994 non-null   int64
#  9   Liveness                1994 non-null   int64
#  10  Valence                 1994 non-null   int64
#  11  Length (Duration)       1994 non-null   str
#  12  Acousticness            1994 non-null   int64
#  13  Speechiness             1994 non-null   int64
#  14  Popularity              1994 non-null   int64
# ...

# %% [markdown]
# Podemos notar de primera mano que el tipo de dato para la columna "Length (Duration)" no es el correcto (str), el cual debe ser corregido/cambiado a tipo 'int'

# %%
# Visualizamos la información estadística de las columnas numéricas del dataframe de Spotify
raw_spotify_data.describe()
# Out:
#              Index         Year  Beats Per Minute (BPM)       Energy  \
# count  1994.000000  1994.000000             1994.000000  1994.000000
# mean    997.500000  1992.992979              120.215647    59.679539
# std     575.762538    16.116048               28.028096    22.154322
# min       1.000000  1956.000000               37.000000     3.000000
# 25%     499.250000  1979.000000               99.000000    42.000000
# 50%     997.500000  1993.000000              119.000000    61.000000
# 75%    1495.750000  2007.000000              136.000000    78.000000
# max    1994.000000  2019.000000              206.000000   100.000000
#
#        Danceability  Loudness (dB)     Liveness      Valence  Acousticness  \
# count   1994.000000    1994.000000  1994.000000  1994.000000   1994.000000
# mean      53.238215      -9.008526    19.012036    49.408726     28.858074
# std       15.351507       3.647876    16.727378    24.858212     29.011986
# ...

# %% [markdown]
# También podemos notar que la primer columna llamada 'Index' no aporta valor a la infromación, podría eliminarse más adelante.

# %% [markdown]
# ### Grammy Awards dataframe

# %%
# Visualizamos las información general del dataframe de los Grammy Awards
raw_grammy_data.info()
raw_grammy_data.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4810 entries, 0 to 4809
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          4810 non-null   int64
#  1   title         4810 non-null   str
#  2   published_at  4810 non-null   str
#  3   updated_at    4810 non-null   str
#  4   category      4810 non-null   str
#  5   nominee       4804 non-null   str
#  6   artist        2970 non-null   str
#  7   workers       2620 non-null   str
#  8   img           3443 non-null   str
#  9   winner        4810 non-null   bool
# dtypes: bool(1), int64(1), str(8)
# memory usage: 343.0 KB
#    year                              title               published_at  \
# 0  2019  62nd Annual GRAMMY Awards  (2019)  2020-05-19T05:10:28-07:00
# 1  2019  62nd Annual GRAMMY Awards  (2019)  2020-05-19T05:10:28-07:00
# 2  2019  62nd Annual GRAMMY Awards  (2019)  2020-05-19T05:10:28-07:00
# ...

# %% [markdown]
# Podemos notar que al igual, los tipos de datos para las columnas con fechas no son los correctos ('str'), deben ser corregitos a datatime.

# %%
# Visualizamos la información estadística de las columnas numéricas del dataframe de los Grammy Awards
raw_grammy_data.describe(include='all')
# Out:
#                year                              title  \
# count   4810.000000                               4810
# unique          NaN                                 62
# top             NaN  62nd Annual GRAMMY Awards  (2019)
# freq            NaN                                433
# mean    1995.566944                                NaN
# std       17.149720                                NaN
# min     1958.000000                                NaN
# 25%     1983.000000                                NaN
# 50%     1998.000000                                NaN
# 75%     2010.000000                                NaN
# max     2019.000000                                NaN
#
#                      published_at                 updated_at  \
# count                        4810                       4810
# unique                          4                         10
# top     2017-11-28T00:03:45-08:00  2019-09-10T01:08:19-07:00
# ...

# %% [markdown]
# La información contenida en el segundo dataframe de los Grammy Awards, parece no ser tan relevante más que la columna 'winner' y porbablmente el 'year'.

# %% [markdown]
# ## Datos únicos, nulos y/o duplicados

# %%
# Revisamos la cantidad de valores únicos en cada columna del dataframe de Spotify
raw_spotify_data.nunique()
# Out:
# Index                     1994
# Title                     1958
# Artist                     731
# Top Genre                  149
# Year                        63
# Beats Per Minute (BPM)     145
# Energy                      98
# Danceability                84
# Loudness (dB)               23
# Liveness                    94
# Valence                     97
# Length (Duration)          350
# Acousticness               100
# Speechiness                 37
# Popularity                  81
# dtype: int64

# %%
# Revisamos la cantidad de valores únicos en cada columna del dataframe de Grammy Awards
raw_grammy_data.nunique()
# Out:
# year              62
# title             62
# published_at       4
# updated_at        10
# category         638
# nominee         4131
# artist          1658
# workers         2366
# img             1463
# winner             1
# dtype: int64
